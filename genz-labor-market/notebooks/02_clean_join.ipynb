# %% [markdown]
# # 02 — Clean + Join
# Builds the monthly analytic dataset and quarterly earnings dataset, then adds derived features.
#
# Outputs:
# - data/processed/monthly_labor_market.csv
# - data/processed/earnings_quarterly.csv
# - data/processed/monthly_labor_market_features.csv

# %%
# !python -m src.clean
# !python -m src.features
