# %% [markdown]
# # 03 — Analysis
# Computes: historic percentile rank, Great Recession and 2020 peaks, rolling z-scores, and 24/60-month trends.
#
# Outputs:
# - data/processed/analysis_summary.json
# - reports/genz_labor_market_report.md

# %%
# !python -m src.analysis
