# %% [markdown]
# # 01 — Acquire data
# Downloads public FRED CSV time series with no API keys and writes provenance metadata.
#
# Outputs:
# - data/raw/*.csv
# - data/metadata/*.metadata.json

# %%
# !python -m src.fetch_sources
